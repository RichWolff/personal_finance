# %%
# %load_ext autoreload
# %autoreload 2

# %%
from elt.load import read_raw_transactions, ingest_all_files
from elt.extract import load_mint, last_n_days, extract_last_30_days, extract_last_365_days
import datetime as dt
import os
import matplotlib.pyplot as plt
import numpy as np
from io import StringIO
import requests

# %%
extract_last_30_days()
ingest_all_files()
# Out:
# [{'C:\\Users\\riwolff\\Documents\\mint_scraper\\personal_finance\\data\\raw\\transactions_2020-01-21_2020-02-20.csv': 0}]

# %%
df = read_raw_transactions()
df.insert(0,'year', df['date'].dt.year)
df.insert(1,'month', ('0'+df['date'].dt.month.astype(str)).str[-2:])
df.insert(3,'day', df['date'].dt.day)
df.insert(4,'year-month', df.year.astype(str) + '-' + df.month.astype(str))
df['amount'] = np.where(df['transaction_type']=='debit',np.abs(df['amount'])*-1,df['amount'])
grp = df.groupby(['year-month','day','category'],as_index=False)['amount'].sum()

varSpend = grp[grp['category'] == 'Variable Spending'].copy()
pivotMTD = varSpend.pivot_table('amount','day','year-month',aggfunc=np.sum).fillna(0).cumsum()
pivotMTD.loc[20,'2020-02']
# Out:
# -3545.27

# %%
from email_budget import get_chart, send_email

# %%
today = dt.date.today()

# Contants
budget = 4300
current_year = today.year
current_month = ('0' + str(today.month))[-2:]
current_day = (today - dt.timedelta(1)).day
days_in_month = 29
current_spend = abs(pivotMTD.loc[current_day,f'{current_year}-{current_month}'])

fig = get_chart(current_spend, budget, current_day, days_in_month, current_year, 'February')
ImgFileName = f'budget_attainment_charts/wolff_budget_{current_year}-{current_month}-{current_day}.png'
fig.savefig(ImgFileName, bbox_inches = 'tight', pad_inches = .1)
plt.close()

send_email('February 2020 Budget Throug The 20th', ImgFileName)

# %%
fig

# %% [markdown]
# Category = ['Variable Spending', 'Bills', 'Transfers', 'Auto Costs', 'Income']
#
# ### Variable Spending
#
# - Expenses that are not recurring
#
# ### Bills / Subscriptions
# - Recurring Expenses Every Given Period

# %%
# Out:
# (221, b'2.0.0 closing connection s48sm1678749qtc.96 - gsmtp')

# %%
SendMail(fname, 'Testing')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-132-ea6eb0761fc1> in <module>
# ----> 1 SendMail(fname, 'Testing')
#
# <ipython-input-131-10b036e1088e> in SendMail(ImgFileName, subject)
#      22     s.ehlo()
#      23     s.login(os.getenv('MINT_MFA_IMAP_ACCOUNT'), os.getenv('MINT_MFA_IMAP_PWD'))
# ---> 24     s.sendmail(msg['To'], msg['From'], msg)
#      25     s.quit()
#
# ~\AppData\Local\Continuum\anaconda3\envs\mint_scraper\lib\smtplib.py in sendmail(self, from_addr, to_addrs, msg, mail_options, rcpt_options)
#     880             self._rset()
#     881             raise SMTPRecipientsRefused(senderrs)
# --> 882         (code, resp) = self.data(msg)
#     883         if code != 250:
#     884             if code == 421:
#
# ~\AppData\Local\Continuum\anaconda3\envs\mint_scraper\lib\smtplib.py in data(self, msg)
#     562             if isinstance(msg, str):
# ...
